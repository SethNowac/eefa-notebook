# %% [markdown]
# ## Import libraries

# %%
import ee
import geemap
import geemap.chart as ui_chart
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Create an interactive map

# %%
Map = geemap.Map(center=[40, -100], zoom=4)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Add Earth Engine Python script

# %%
# Add Earth Engine dataset
image = ee.Image("USGS/SRTMGL1_003")

#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Chapter:      A2.1 Groundwater Monitoring with GRACE
#  Checkpoint:   A21b
#  Authors:      A.J. Purdy, J.S. Famiglietti
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# Import Basins.
basins = ee.FeatureCollection('USGS/WBD/2017/HUC04')

# Extract the 3 HUC 04 basins for the Central Valley.
codes = ['1802', '1803', '1804']
basin = basins.filter(ee.Filter.inList('huc4', codes))

# Add the basin to the map to show the extent of our analysis.
Map.centerObject(basin, 6)
Map.addLayer(basin, {
    'color': 'green'
}, 'Central Valley Basins', True, 0.5)

landcover = ee.ImageCollection('USDA/NASS/CDL') \
.filter(ee.Filter.date('2019-01-01', '2019-12-31')) \
.select('cultivated')

Map.addLayer(landcover.first().clip(basin), {}, 'Cropland', True,
0.5)

# This table was generated using the index from the CDEC website
res = ee.FeatureCollection(
'projects/gee-book/assets/A2-1/ca_reservoirs_index')
# Filter reservoir locations by the Central Valley geometry
res_cv = res.filterBounds(basin)
Map.addLayer(res_cv, {
    'color': 'blue'
}, 'Reservoirs')

# -----------------------------------------------------------------------
# CHECKPOINT
# -----------------------------------------------------------------------

GRACE = ee.ImageCollection('NASA/GRACE/MASS_GRIDS/MASCON_CRI')
# Subset GRACE for liquid water equivalent dataset
basinTWSa = GRACE.select('lwe_thickness')

# Make plot of TWSa for Basin Boundary
TWSaChart = ui_chart.image_series(
image_collection = basinTWSa.filter(ee.Filter.date(
'2003-01-01', '2016-12-31')),
region = basin,
reducer = ee.Reducer.mean(),
)
TWSaChart.set_options(options={
'title': 'TWSa',
'hAxis': {
    'format': 'MM-yyyy'
},
'vAxis': {
    'title': 'TWSa (cm)'
},
'lineWidth': 1,
})
TWSaChart.display()

# Compute Trend for each pixel to map regions of most change

def func_jer(image):
    # Compute time in fractional years since the epoch.
    date = ee.Date(image.get('system:time_start'))
    years = date.difference(ee.Date('2003-01-01'), 'year')
    # Return the image with the added bands.
    return image \
    .addBands(ee.Image(years).rename('t').float()) \
    .addBands(ee.Image.constant(1))

addVariables = func_jer










cvTWSa = basinTWSa.filterBounds(basin).map(addVariables)
print(cvTWSa.getInfo())
# List of the independent variable names
independents = ee.List(['constant', 't'])

# Name of the dependent variable.
dependent = ee.String('lwe_thickness')
# Compute a linear trend.  This will have two bands: 'residuals' and
# a 2x1 band called coefficients (columns are for dependent variables).
trend = cvTWSa.select(independents.add(dependent)) \
.reduce(ee.Reducer.linearRegression(independents.length(), 1))

# Flatten the coefficients into a 2-band image
coefficients = trend.select('coefficients') \
.arrayProject([0]) \
.arrayFlatten([independents])

# Create a layer of the TWSa slope to add to the map
slope = coefficients.select('t')
# Set visualization parameters to represent positive (blue) & negative (red) trends
slopeParams = {
    'min': -3.5,
    'max': 3.5,
    'palette': ['red', 'white', 'blue']
}
Map.addLayer(slope.clip(basin), slopeParams, 'TWSa Trend', True,
0.75)

# -----------------------------------------------------------------------
# CHECKPOINT
# -----------------------------------------------------------------------
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Figure(axes=[Axis(label_offset='30px', scale=DateScale()), Axis(label_offset='40px', orientation='vertical', s…
# {'type': 'ImageCollection', 'bands': [], 'version': 1641990519969535, 'id': 'NASA/GRACE/MASS_GRIDS/MASCON_CRI', 'properties': {'date_range': [1017532800000, 1498608000000], 'period': 0, 'system:visualization_0_min': '-25.0', 'type_name': 'ImageCollection', 'keywords': ['grace', 'gravity', 'jpl', 'mascon', 'mass', 'nasa', 'tellus', 'water'], 'system:visualization_0_bands': 'lwe_thickness', 'system:is_global': 1, 'thumb': 'https://mw1.google.com/ges/dd/images/GRACE_MASCON_thumb.png', 'description': '<p>GRACE Tellus Monthly Mass Grids provides monthly\ngravitational anomalies relative to a 2004-2010 time-mean baseline.\nThe data contained in this dataset are units of &quot;Equivalent Water Thickness&quot;\nwhich represent the deviations of mass in terms of vertical extent\nof water in centimeters. See the provider&#39;s <a href="https://grace.jpl.nasa.gov/data/monthly-mass-grids/">Monthly Mass\nGrids Overview</a>\nfor more details.</p><p>The GRACE Tellus (GRCTellus) Global Mascon dataset\nis based on Level-1 GRACE observations and processed\nat NASA Jet Propulsion Laboratory (JPL).</p><p>This dataset uses a-priori constraints in space and time to\nestimate global, monthly gravity fields in terms of equal-area\n3°x3° spherical cap mass concentration (mascon) functions to minimize the\neffect of measurement errors. This results in better S/N\nratios of the mascon fields compared to the conventional\nspherical-harmonic solutions.</p><p>This version of the Global Mascon dataset has a Coastline Resolution\nImprovement (CRI) filter applied to separate the land and ocean\nportions of mass within each land/ocean mascon in a post-processing step.\nFor users who wish to do their own separation of land and ocean mass\nsignals, a version of the data without the CRI filter is available\nat <a href="https://developers.google.com/earth-engine/datasets/catalog/NASA_GRACE_MASS_GRIDS_MASCON">NASA/GRACE/MASS_GRIDS/MASCON</a>.</p><p><strong>Note</strong></p><ul><li><p>A set of global gain factors to aid in the interpretation of signals\nat sub-mascon resolution is available at\n<a href="https://code.earthengine.google.com/?asset=NASA/GRACE/MASS_GRIDS/MASCON_SCALE_CRI_2015">NASA/GRACE/MASS_GRIDS/MASCON_SCALE_CRI_2015</a>.\n<strong>Please note</strong>: the gain factors can be used for hydrology-related\nsignals, but not for mountain glaciers or ice sheets. For more\ninformation on scaling the mascon solutions, please see <a href="https://doi.org/10.1002/2016WR019344">Wiese et al.\n(2016)</a>.</p></li><li><p>The data are represented on a 1/2 degree lon-lat grid, but they\nrepresent the 3x3 degree equal-area caps, which is the current\nnative resolution of JPL-RL05M.</p></li></ul><p><b>Provider: <a href="https://grace.jpl.nasa.gov/data/get-data/jpl_global_mascons/">NASA Jet Propulsion Laboratory</a></b><br><p><b>Resolution</b><br>55660 meters\n</p><p><b>Bands</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Description</th></tr><tr><td>lwe_thickness</td><td><p>Equivalent liquid water thickness in centimeters.</p></td></tr><tr><td>uncertainty</td><td><p>1-sigma uncertainty for each 3-degree mascon estimate.\nThe provided estimates of uncertainty are regarded to be conservative.\nSee the provider&#39;s <a href="https://grace.jpl.nasa.gov/data/get-data/jpl_global_mascons/">Error &amp; Uncertainty Estimates\nsection</a></p></td></tr></table><p><b>Terms of Use</b><br><p>All NASA-produced data from the GRACE mission is made freely available\nfor the public to use. When using any of the GRCTellus data, please\nadd an acknowledgment: &quot;GRACE land are available at\nhttps://grace.jpl.nasa.gov,\nsupported by the NASA MEaSUREs Program.&quot; and cite with the\ncitations provided.</p><p><b>Suggested citation(s)</b><ul><li><p>D.N. Wiese. 2015. GRACE monthly global water mass grids NETCDF\nRELEASE 5.0. Ver. 5.0. PO.DAAC, CA, USA.. Dataset accessed [YYYY-MM-DD] at\n<a href="https://doi.org/10.5067/TEMSC-OCL05">https://doi.org/10.5067/TEMSC-OCL0 ...

# %% [markdown]
# ## Display the interactive map

# %%
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[38.31357121524816, -120.5757424837751], controls=(WidgetControl(options=['position', 'transparent_…
