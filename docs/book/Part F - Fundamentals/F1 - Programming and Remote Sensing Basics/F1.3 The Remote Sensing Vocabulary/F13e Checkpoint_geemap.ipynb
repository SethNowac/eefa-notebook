# %% [markdown]
# ## Import libraries

# %%
import ee
import geemap
import geemap.chart as chart
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Create an interactive map

# %%
Map = geemap.Map(center=[40, -100], zoom=4)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Add Earth Engine Python script

# %%
# Add Earth Engine dataset
image = ee.Image("USGS/SRTMGL1_003")

#*** Start of imports. If edited, may not auto-convert in the playground. ***#
msi = ee.ImageCollection("COPERNICUS/S2")
naip = ee.ImageCollection("USDA/NAIP/DOQQ")
eo1 = ee.ImageCollection("EO1/HYPERION")
tm = ee.ImageCollection("LANDSAT/LT05/C02/T1")
mod09 = ee.ImageCollection("MODIS/061/MOD09A1")
#**** End of imports. If edited, may not auto-convert in the playground. ****#
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Chapter:      F1.3 The Remote Sensing Vocabulary
#  Checkpoint:   F13e
#  Authors:      K. Dyson, A. P. Nicolau, D. Saah, and N. Clinton
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
###
# Explore spatial resolution
###

# Define a region of interest as a point at San Francisco airport.
sfoPoint = ee.Geometry.Point(-122.3774, 37.6194)

# Center the map at that point.
Map.centerObject(sfoPoint, 16)

# MODIS
# Get an image from your imported MODIS MYD09GA collection.
modisImage = mod09.filterDate('2020-02-01', '2020-03-01').first()

# Use these MODIS bands for near infrared, red, and green, respectively.
modisBands = ['sur_refl_b02', 'sur_refl_b01', 'sur_refl_b04']

# Define visualization parameters for MODIS.
modisVis = {
    'bands': modisBands,
    'min': 0,
    'max': 3000
}

# Add the MODIS image to the map.
Map.addLayer(modisImage, modisVis, 'MODIS')

# Get the scale of the data from the NIR band's projection:
modisScale = modisImage.select('sur_refl_b02') \
.projection().nominalScale()

print('MODIS NIR scale:', modisScale.getInfo())

# TM
# Filter TM imagery by location and date.

tmImage = tm \
.filterBounds(ee.Geometry.Point([Map.get_center()[1], Map.get_center()[0]])) \
.filterDate('1987-03-01', '1987-08-01') \
.first()

# Display the TM image as a False color composite.
Map.addLayer(tmImage, {
    'bands': ['B4', 'B3', 'B2'],
    'min': 0,
    'max': 100
}, 'TM')

# Get the scale of the TM data from its projection:
tmScale = tmImage.select('B4') \
.projection().nominalScale()

print('TM NIR scale:', tmScale.getInfo())

# MSI
# Filter MSI imagery by location and date.
msiImage = msi \
.filterBounds(ee.Geometry.Point([Map.get_center()[1], Map.get_center()[0]])) \
.filterDate('2020-02-01', '2020-04-01') \
.first()

# Display the MSI image as a False color composite.
Map.addLayer(msiImage, {
    'bands': ['B8', 'B4', 'B3'],
    'min': 0,
    'max': 2000
}, 'MSI')

# Get the scale of the MSI data from its projection:
msiScale = msiImage.select('B8') \
.projection().nominalScale()
print('MSI scale:', msiScale.getInfo())

# NAIP
# Get NAIP images for the study period and region of interest.
naipImage = naip \
.filterBounds(ee.Geometry.Point([Map.get_center()[1], Map.get_center()[0]])) \
.filterDate('2018-01-01', '2018-12-31') \
.first()

# Display the NAIP mosaic as a color-IR composite.
Map.addLayer(naipImage, {
    'bands': ['N', 'R', 'G']
}, 'NAIP')

# Get the NAIP resolution from the first image in the mosaic.
naipScale = naipImage.select('N') \
.projection().nominalScale()

print('NAIP NIR scale:', naipScale.getInfo())

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------

##/
# Explore Temporal Resolution
##/

# Use Print to see Landsat revisit time
print('Landsat-5 series:', tm \
.filterBounds(ee.Geometry.Point([Map.get_center()[1], Map.get_center()[0]])) \
.filterDate('1987-06-01', '1987-09-01').getInfo())

# Create a chart to see Landsat 5's 16 day revisit time.
tmChart = chart.image_series(
image_collection = tm.select('B4').filterDate('1987-06-01',
'1987-09-01'),
region = sfoPoint
)

# Define a chart style that will let us see the individual dates.
chartStyle = {
    'hAxis': {
            'title': 'Date'
        },
    'vAxis': {
            'title': 'NIR Mean'
        },
    'series': {
            '0': {
                        'lineWidth': 3,
                        'pointSize': 6
                    }
        },
}

# Apply custom style properties to the chart.
tmChart.set_options(options = chartStyle)

# Print the chart.
print('TM Chart')

tmChart.display()

# Sentinel-2 has a 5 day revisit time.
msiChart = chart.image_series(
image_collection = msi.select('B8').filterDate('2020-06-01',
'2020-09-01'),
region = sfoPoint
)#.setSeriesNames(['NIR'])

# Apply the previously defined custom style properties to the chart.
msiChart.set_options(options = chartStyle)

# Print the chart.
print('MSI Chart')

msiChart.display()

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------

##/
# Explore spectral resolution
##/

# Get the MODIS band names as an ee.List
modisBands = modisImage.bandNames()

# Print the list.
print('MODIS bands:', modisBands.getInfo())

# Print the length of the list.
print('Length of the bands list:', modisBands.length().getInfo())

# Graph the MODIS spectral bands (bands 11-17).

# Select only the reflectance bands of interest.
reflectanceImage = modisImage.select(
'sur_refl_b01',
'sur_refl_b02',
'sur_refl_b03',
'sur_refl_b04',
'sur_refl_b05',
'sur_refl_b06',
'sur_refl_b07'
)

# Define an object of customization parameters for the chart.
options = {
    'title': 'MODIS spectrum at SFO',
    'hAxis': {
            'title': 'Band'
        },
    'vAxis': {
            'title': 'Reflectance'
        },
    'legend': {
            'position': 'none'
        },
    'pointSize': 3
}

# Make the chart.
modisReflectanceChart = chart.image_regions(
image = reflectanceImage,
regions = sfoPoint
).set_options(options = options)

# Display the chart.
#print(modisReflectanceChart.getInfo())

modisReflectanceChart.display()

# Get the EO-1 band names as a ee.List
eo1Image = eo1 \
.filterDate('2015-01-01', '2016-01-01') \
.first()

# Extract the EO-1 band names.
eo1Bands = eo1Image.bandNames()

# Print the list of band names.
print('EO-1 bands:', eo1Bands.getInfo())

# Create an options object for our chart.
optionsEO1 = {
    'title': 'EO1 spectrum',
    'hAxis': {
            'title': 'Band'
        },
    'vAxis': {
            'title': 'Reflectance'
        },
    'legend': {
            'position': 'none'
        },
    'pointSize': 3
}

# Make the chart and set the options.
eo1Chart = chart.image_regions(
image = eo1Image,
regions = ee.Geometry.Point([6.10, 81.12])
).set_options(optionsEO1)

# Display the chart.
#print(eo1Chart.getInfo())

eo1Chart.display()

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------

##/
# Examine pixel quality
##/

# Sentinel Quality Visualization.
msiCloud = msi \
.filterBounds(ee.Geometry.Point([Map.get_center()[1], Map.get_center()[0]])) \
.filterDate('2019-12-31', '2020-02-01') \
.first()

# Display the MSI image as a False color composite.
Map.addLayer(msiCloud,
{
    'bands': ['B8', 'B4', 'B3'],
    'min': 0,
    'max': 2000
},
'MSI Quality Image')

Map.addLayer(msiCloud,
{
    'bands': ['QA60'],
    'min': 0,
    'max': 2000
},
'Sentinel Quality Visualization')

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------

##/
# Metadata
##/
print('MSI Image Metadata', msiImage.getInfo())

# Image-level Cloud info
msiCloudiness = msiImage.get('CLOUDY_PIXEL_PERCENTAGE')

print('MSI CLOUDY_PIXEL_PERCENTAGE:', msiCloudiness.getInfo())

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# MODIS NIR scale: 463.31271652791656
# TM NIR scale: 30
# MSI scale: 10
# NAIP NIR scale: 0.6
# Landsat-5 series: {'type': 'ImageCollection', 'bands': [], 'version': 1723844062719139, 'id': 'LANDSAT/LT05/C02/T1', 'features': [{'type': 'Image', 'bands': [{'id': 'B1', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'QA_PIXEL', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'QA_RADSAT', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'SAA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'SZA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'VAA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}, {'id': 'VZA', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': -32768, 'max': 32767}, 'dimensions': [7831, 7071], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 463485, 0, -30, 4253415]}], 'version': 1652689674940109, 'id': 'LANDSAT/LT05/C02/T1/LT05_044034_19870612', 'properties': {'RADIANCE_MULT_BAND_5': 0.12035, 'RADIANCE_MULT_BAND_6': 0.055375, 'IMAGE_QUALITY': 9, 'RADIANCE_MULT_BAND_3': 1.044, 'RADIANCE_MULT_BAND_4': 0.87602, 'RADIANCE_MULT_BAND_1': 0.67134, 'RADIANCE_MULT_BAND_2': 1.3222, 'WRS_TYPE': 2, 'K2_CONSTANT_BAND_6': 1260.56, 'CORRECTION_GAIN_BAND_2': 'CPF', 'CORRECTION_GAIN_BAND_1': 'CPF', 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-120.9095337918459, 38.12898894489212], [-121.48800450629115, 38.21728730908248], [-122.95663333396601, 38.42776083898684], [-122.96465425070922, 38.40350760042752], [-123.0243762531066, 38.20086171159077], [-123.40527267915479, 36.86245494272328], [-123.40987378570976, 36.84050386979543], [-123.40978265734245, 36.823422853159435], [-121.26090158250697, 36.50836844493247], [-121.24924266867083, 36.51523349003538], [-121.24266283316389, 36.521429121152295], [-121.20977056072655, 36.624840412133], [-121.07341367030749, 37.05994547077483], [-121.00087584480772, 37.29073115360436], [-120.87956567603982, 37.67381330558904], [-120.78970144544084, 37.956638826885246], [-120.75721908369522, 38.05902450318483], [-120.74689517890766, 38.094280599635034], [-120.74738915551185, 38.10129935738072], [-120.75958141619 ...
# TM Chart
# Figure(axes=[Axis(label_offset='30px', scale=LinearScale()), Axis(label_offset='40px', orientation='vertical',…
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\data.py:402, in _execute_cloud_call(call, num_retries)
#     401 try:
# --> 402   return call.execute(num_retries=num_retries)
#     403 except googleapiclient.errors.HttpError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/table:computeFeatures?alt=json returned "User memory limit exceeded.". Details: "User memory limit exceeded.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geemap\common.py:9132, in ee_to_df(ee_object, columns, remove_geom, sort_columns, **kwargs)
#    9130 kwargs["fileFormat"] = "PANDAS_DATAFRAME"
# -> 9132 df = ee.data.computeFeatures(kwargs)
#    9134 if isinstance(columns, list):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\data.py:1005, in computeFeatures(params)
#    1004 if converter:
# -> 1005   return converter.do_conversion(_generate(call, 'features', params=params))
#    1006 return call(params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\table_converter.py:23, in PandasConverter.do_conversion(self, features)
#      20   raise ImportError(
#      21       'Using format PANDAS_DATAFRAME requires pandas.'
#      22   ) from exc
# ---> 23 return pandas.DataFrame.from_records(self._convert_to_records(features))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:2438, in DataFrame.from_records(cls, data, index, exclude, columns, coerce_float, nrows)
#    2437 try:
# -> 2438     first_row = next(data)
#    2439 except StopIteration:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\table_converter.py:28, in PandasConverter._convert_to_records(self, features)
#      25 def _convert_to_records(
#      26     self, features: Iterator[Any]
#      27 ) -> Iterator[Dict[str, Any]]:
# ---> 28   for feature in features:
#      29     yield {
#      30         'geo': feature.get('geometry'),
#      31         **(feature.get('properties', {}) or {}),
#      32     }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\data.py:802, in _generate(func, list_key, **kwargs)
#     801 while True:
# --> 802   response = func(**args)
#     803   for obj in response.get(list_key, []):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\data.py:996, in computeFeatures.<locals>.call(params)
#     995 def call(params):
# --> 996   return _execute_cloud_call(
#     997       _get_cloud_projects()
#     998       .table()
#     999       .computeFeatures(project=_get_projects_path(), body=params)
#    1000   )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ee\data.py:404, in _execute_cloud_call(call, num_retries)
#     403 except googleapiclient.errors.HttpError as e:
# --> 404   raise _translate_cloud_exception(e)
#
# EEException: User memory limit exceeded.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20512\2959168157.py in ?()
#     148
#     149 tmChart.display()
#     150
#     151 # Sentinel-2 has a 5 day revisit time.
# --> 152 msiChart = chart.image_series(
#     153 image_collection = msi.select('B8').filterDate('2020-06-01',
#     154 '2020-09-01'),
#     155 region = sfoPoint
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geemap\chart.py in ?(image_collection, region, reducer, scale, x_property, chart_type, x_cols, y_cols, colors, title, x_label, y_label, **kwargs)
#    1871     # Apply the function over the image collection.
#    1872     fc = ee.FeatureCollection(
#    1873         image_collection.map(get_stats).filter(ee.Filter.notNull(band_names))
#    1874     )
# -> 1875     df = ee_to_df(fc)
#    1876     if "date" in df.columns:
#    1877         df["date"] = pd.to_datetime(df["date"])
#    1878
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geemap\common.py in ?(ee_object, columns, remove_geom, sort_columns, **kwargs)
#    9141             df = df.reindex(sorted(df.columns), axis=1)
#    9142
#    9143         return df
#    9144     except Exception as e:
# -> 9145         raise Exception(e)
#
# Exception: User memory limit exceeded.

# %% [markdown]
# ## Display the interactive map

# %%
Map
