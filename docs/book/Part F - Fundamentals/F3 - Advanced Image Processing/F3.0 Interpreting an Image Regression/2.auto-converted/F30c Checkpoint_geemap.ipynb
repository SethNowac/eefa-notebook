# %% [markdown]
# ## Import libraries

# %%
import ee
import geemap

# %% [markdown]
# ## Create an interactive map

# %%
Map = geemap.Map(center=[40, -100], zoom=4)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Add Earth Engine Python script

# %%
# Add Earth Engine dataset
image = ee.Image("USGS/SRTMGL1_003")

#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Chapter:      F3.0 Interpreting an Image: Regression
#  Checkpoint:   F30c
#  Authors:      K. Dyson, A. Nicolau, D. Saah, N. Clinton
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# Define a Turin polygon.
Turin = ee.Geometry.Polygon(
[
[
[7.455553918110218, 45.258245019259036],
[7.455553918110218, 44.71237367431335],
[8.573412804828967, 44.71237367431335],
[8.573412804828967, 45.258245019259036]
]
], None, False)

# Center on Turin
Map.centerObject(Turin, 9)

mod44b = ee.ImageCollection('MODIS/006/MOD44B')

##/
# Start Linear Fit
##/

# Put together the dependent variable by filtering the
# ImageCollection to just the 2020 image near Turin and
# selecting the percent tree cover band.
percentTree2020 = mod44b \
.filterDate('2020-01-01', '2021-01-01') \
.first() \
.clip(Turin) \
.select('Percent_Tree_Cover')

# You can print information to the console for inspection.
print('2020 Image', percentTree2020.getInfo())

Map.addLayer(percentTree2020, {
    'max': 100
}, 'Percent Tree Cover')

landsat8_raw = ee.ImageCollection('LANDSAT/LC08/C02/T1_RT')

# Put together the independent variable.
landsat8filtered = landsat8_raw \
.filterBounds(Turin.centroid(
maxError = 1
)) \
.filterDate('2020-04-01', '2020-4-30') \
.first()

print('Landsat8 filtered', landsat8filtered.getInfo())

# Display the L8 image.
visParams = {
    'bands': ['B4', 'B3', 'B2'],
    'max': 16000
}
Map.addLayer(landsat8filtered, visParams, 'Landsat 8 Image')

# Calculate NDVI which will be the independent variable.
ndvi = landsat8filtered.normalizedDifference(['B5', 'B4'])

# Create the training image.
trainingImage = ndvi.addBands(percentTree2020)
print('training image for linear fit', trainingImage.getInfo())


# Independent variable first, dependent variable second.
# You need to include the scale variable.
linearFit = trainingImage.reduceRegion(
reducer = ee.Reducer.linearFit(),
geometry = Turin,
scale = 30,
bestEffort = True
)

# Inspect the results.
print('OLS estimates:', linearFit.getInfo())
print('y-intercept:', linearFit.get('offset').getInfo())
print('Slope:', linearFit.get('scale').getInfo())

# Create a prediction based on the linearFit model.
predictedTree = ndvi.expression(
'intercept + slope * ndvi', {
    'ndvi': ndvi.select('nd'),
    'intercept': ee.Number(linearFit.get('offset')),
    'slope': ee.Number(linearFit.get('scale'))
})

print('predictedTree', predictedTree.getInfo())

# Display the results.
Map.addLayer(predictedTree, {
    'max': 100
}, 'Predicted Percent Tree Cover')

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------

###
# Start Linear Regression
###

# Assemble the independent variables.
predictionBands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7',
'B10', 'B11'
]

# Create the training image stack for linear regression.
trainingImageLR = ee.Image(1) \
.addBands(landsat8filtered.select(predictionBands)) \
.addBands(percentTree2020)

print('Linear Regression training image:', trainingImageLR.getInfo())

# Compute ordinary least squares regression coefficients using
# the linearRegression reducer.
linearRegression = trainingImageLR.reduceRegion(
reducer = ee.Reducer.linearRegression(
numX = 10,
numY = 1
),
geometry = Turin,
scale = 30,
bestEffort = True
)

# Inspect the results.
print('Linear regression results:', linearRegression.getInfo())

# Extract the coefficients as a list.
coefficients = ee.Array(linearRegression.get('coefficients')) \
.project([0]) \
.toList()

print('Coefficients', coefficients.getInfo())

# Create the predicted tree cover based on linear regression.
predictedTreeLR = ee.Image(1) \
.addBands(landsat8filtered.select(predictionBands)) \
.multiply(ee.Image.constant(coefficients)) \
.reduce(ee.Reducer.sum()) \
.rename('predictedTreeLR') \
.clip(landsat8filtered.geometry())

Map.addLayer(predictedTreeLR, {
    'min': 0,
    'max': 100
}, 'LR prediction')

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------

##/
# Start Non-linear Regression
##/
# Create the training data stack.
trainingImageCART = ee.Image(landsat8filtered.select(predictionBands)) \
.addBands(percentTree2020)

# Sample the training data stack.
trainingData = trainingImageCART.sample(
region = Turin,
scale = 30,
numPixels = 1500,
seed = 5
)

# Examine the CART training data.
print('CART training data', trainingData.getInfo())

# Run the CART regression.
cartRegression = ee.Classifier.smileCart() \
.setOutputMode('REGRESSION') \
.train(
features = trainingData,
classProperty = 'Percent_Tree_Cover',
inputProperties = predictionBands
)

# Create a prediction of tree cover based on the CART regression.
cartRegressionImage = landsat8filtered.select(predictionBands) \
.classify(cartRegression, 'cartRegression')

Map.addLayer(cartRegressionImage, {
    'min': 0,
    'max': 100
}, 'CART regression')

##/
# Calculating RMSE to assess model performance
##/

# Concatenate percent tree cover image and all predictions.
concat = ee.Image.cat(percentTree2020,
predictedTree,
predictedTreeLR,
cartRegressionImage) \
.rename([
'TCpercent',
'LFprediction',
'LRprediction',
'CARTprediction'
])

# Sample pixels
sample = concat.sample(
region = Turin,
scale = 30,
numPixels = 500,
seed = 5
)

print('First feature in sample', sample.first().getInfo())

# First step: This function computes the squared difference between
# the predicted percent tree cover and the known percent tree cover

def func_mvl(feature):
    TCpercent = ee.Number(feature.get('TCpercent'))
    diffLFsq = ee.Number(feature.get('LFprediction')) \
    .subtract(TCpercent).pow(2)
    diffLRsq = ee.Number(feature.get('LRprediction')) \
    .subtract(TCpercent).pow(2)
    diffCARTsq = ee.Number(feature.get('CARTprediction')) \
    .subtract(TCpercent).pow(2)

    # Return the feature with the squared difference set to a 'diff' property.
    return feature.set({
        'diffLFsq': diffLFsq,
        'diffLRsq': diffLRsq,
        'diffCARTsq': diffCARTsq
        })

calculateDiff = func_mvl
















# Second step: Calculate RMSE for population of difference pairs.
# Then, map the difference function over the collection.
def func_zcf(i):
    # Take the square root of the mean square differences.
    return ee.Number(i).sqrt()

rmse = ee.List([ee.Number(
sample.map(calculateDiff) \
.reduceColumns(
reducer = ee.Reducer.mean().repeat(3),
selectors = ['diffLFsq', 'diffLRsq',
'diffCARTsq'
]
).get('mean'))
# Flatten the list of lists.
]).flatten().map(func_zcf)




# Print the result.
print('RMSE', rmse.getInfo())

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 2020 Image {'type': 'Image', 'bands': [{'id': 'Percent_Tree_Cover', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [407, 264], 'origin': [88918, 21475], 'crs': 'SR-ORG:6974', 'crs_transform': [231.65635826395825, 0, -20015109.353988, 0, -231.65635826395834, 10007554.676994]}], 'version': 1622919723201563, 'id': 'MODIS/006/MOD44B/2020_03_05', 'properties': {'system:footprint': {'geodesic': False, 'type': 'Polygon', 'coordinates': [[[7.455553918110218, 44.71237367431335], [8.573412804828967, 44.71237367431335], [8.573412804828967, 45.258245019259036], [7.455553918110218, 45.258245019259036], [7.455553918110218, 44.71237367431335]]]}, 'system:time_start': 1583366400000, 'google:max_source_file_timestamp': 1622906226000, 'system:time_end': 1614902400000, 'system:asset_size': 14854503768, 'system:index': '2020_03_05'}}
# Landsat8 filtered {'type': 'Image', 'bands': [{'id': 'B1', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B8', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions':
id': 'constant', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 1, 'max': 1}, 'crs': 'EPSG:4326', 'crs_transform': [1, 0, 0, 0, 1, 0]}, {'id': 'B1', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B10', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'B11', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [7831, 7951], 'crs': 'EPSG:32632', 'crs_transform': [30, 0, 336885, 0, -30, 5058315]}, {'id': 'Percent_Tree_Cover', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 255}, 'dimensions': [407, 264], 'origin': [88918, 21475], 'crs': 'SR-ORG:6974', 'crs_transform': [231.65635826395825, 0, -20015109.353988, 0, -231.65635826395834, 10007554.676994]}]}
# Linear regression results: {'coefficients': [[234.31332453155397], [-0.01845828295987128], [0.007894094774743147], [0.018833235728657235], [-0.0133685067359455], [-0.0023841508627321702], [0.001184499159273253], [0.001270690090230258], [0.0028045860701036572], [-0.008752427028556347]], 'residuals': [9.850661963891604]}
# Coefficients [234.31332453155397, -0.01845828295987128, 0.007894094774743147, 0.018833235728657235, -0.0133685067359455, -0.0023841508627321702, 0.001184499159273253, 0.001270690090230258, 0.0028045860701036572, -0.008752427028556347]
# CART training data {'type': 'FeatureCollection', 'columns': {}, 'properties': {'band_order': ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B10', 'B11', 'Percent_Tree_Cover']}, 'features': [{'type': 'Feature', 'geometry': None, 'id': '0', 'properties': {'B1': 9535, 'B10': 26837, 'B11': 24936, 'B2': 8716, 'B3': 8849, 'B4': 7436, 'B5': 20623, 'B6': 12877, 'B7': 8840, 'Percent_Tree_Cover': 36}}, {'type': 'Feature', 'geometry': None, 'id': '1', 'properties': {'B1': 9756, 'B10': 27501, 'B11': 25549, 'B2': 8884, 'B3': 8506, 'B4': 7930, 'B5': 16603, 'B6': 12551, 'B7': 9205, 'Percent_Tree_Cover': 10}}, {'type': 'Feature', 'geometry': None, 'id': '2', 'properties': {'B1': 10655, 'B10': 28791, 'B11': 26191, 'B2': 10164, 'B3': 10350, 'B4': 11287, 'B5': 14879, 'B6': 15881, 'B7': 13817, 'Percent_Tree_Cover': 8}}, {'type': 'Feature', 'geometry': None, 'id': '3', 'properties': {'B1': 9968, 'B10': 26867, 'B11': 24648, 'B2': 9186, 'B3': 8735, 'B4': 8365, 'B5': 15377, 'B6': 13205, 'B7': 9979, 'Percent_Tree_Cover': 37}}, {'type': 'Feature', 'geometry': None, 'id': '4', 'properties': {'B1': 9822, 'B10': 27374, 'B11': 25283, 'B2': 8970, 'B3': 8443, 'B4': 7455, 'B5': 18926, 'B6': 10766, 'B7': 8055, 'Percent_Tree_Cover': 12}}, {'type': 'Feature', 'geometry': None, 'id': '5', 'properties': {'B1': 9626, 'B10': 28249, 'B11': 26189, 'B2': 8872, 'B3': 8551, 'B4': 7731, 'B5': 14796, 'B6': 11313, 'B7': 8844, 'Percent_Tree_Cover': 6}}, {'type': 'Feature', 'geometry': None, 'id': '6', 'properties': {'B1': 11682, 'B10': 30450, 'B11': 27627, 'B2': 11425, 'B3': 11699, 'B4': 12647, 'B5': 14755, 'B6': 15683, 'B7': 14537, 'Percent_Tree_Cover': 11}}, {'type': 'Feature', 'geometry': None, 'id': '7', 'properties': {'B1': 9694, 'B10': 26789, 'B11': 24939, 'B2': 8858, 'B3': 8617, 'B4': 7435, 'B5': 24682, 'B6': 10824, 'B7': 7688, 'Percent_Tree_Cover': 5}}, {'type': 'Feature', 'geometry': None, 'id': '8', 'properties': {'B1': 10891, 'B10': 30743, 'B11': 27551, 'B2': 10405, 'B3': 10438, 'B4': 11379, 'B5': 13218, 'B6': 13479, 'B7': 12308, 'Percent_Tree_Cover': 28}}, {'type': 'Feature', 'geometry': None, 'id': '9', 'properties': {'B1': 10798, 'B10': 30681, 'B11': 27718, 'B2': 10316, 'B3': 10525, 'B4': 11939, 'B5': 14442, 'B6': 15989, 'B7': 14722, 'Percent_Tree_Cover': 11}}, {'type': 'Feature', 'geometry': None, 'id': '10', 'properties': {'B1': 9728, 'B10': 27990, 'B11': 25638, 'B2': 8835, 'B3': 8319, 'B4': 7436, 'B5': 20465, 'B6': 12283, 'B7': 8256, 'Percent_Tree_Cover': 20}}, {'type': 'Feature', 'geometry': None, 'id': '11', 'properties': {'B1': 9752, 'B10': 27511, 'B11': 25230, 'B2': 8888, 'B3': 8405, 'B4': 7466, 'B5': 19367, 'B6': 11774, 'B7': 8379, 'Percent_Tree_Cover': 22}}, {'type': 'Feature', 'geometry': None, 'id': '12', 'properties': {'B1': 9643, 'B10': 25026, 'B11': 23323, 'B2': 8784, 'B3': 8045, 'B4': 7596, 'B5': 11532, 'B6': 10226, 'B7': 8168, 'Percent_Tree_Cover': 52}}, {'type': 'Feature', 'geometry': None, 'id': '13', 'properties': {'B1': 9982, 'B10': 27484, 'B11': 25543, 'B2': 9286, 'B3': 8970, 'B4': 8748, 'B5': 16948, 'B6': 15090, 'B7': 11089, 'Percent_Tree_Cover': 13}}, {'type': 'Feature', 'geometry': None, 'id': '14', 'properties': {'B1': 9837, 'B10': 27736, 'B11': 25259, 'B2': 9014, 'B3': 8614, 'B4': 7859, 'B5': 18047, 'B6': 12729, 'B7': 9118, 'Percent_Tree_Cover': 25}}, {'type': 'Feature', 'geometry': None, 'id': '15', 'properties': {'B1': 10935, 'B10': 29693, 'B11': 27130, 'B2': 10634, 'B3': 11092, 'B4': 11845, 'B5': 15761, 'B6': 16746, 'B7': 14513, 'Percent_Tree_Cover': 8}}, {'type': 'Feature', 'geometry': None, 'id': '16', 'properties': {'B1': 11709, 'B10': 33130, 'B11': 29693, 'B2': 11317, 'B3': 10948, 'B4': 11216, 'B5': 12280, 'B6': 13484, 'B7': 12808, 'Percent_Tree_Cover': 10}}, {'type': 'Feature', 'geometry': None, 'id': '17', 'properties': {'B1': 9992, 'B10': 26905, 'B11': 24670, 'B2': 9214, 'B3': 8768, 'B4': 8526, 'B5': 14835, 'B6': 15094, 'B7': 10976, 'Percent_Tree_Cover': 42}}, {'type': 'Feature', 'geometry': None, 'id': '18', 'properties': {'B1' ...
# First feature in sample {'type': 'Feature', 'geometry': None, 'id': '0', 'properties': {'CARTprediction': 37, 'LFprediction': 20.960366280485186, 'LRprediction': 28.69912224900216, 'TCpercent': 37}}
# RMSE [13.886897157352005, 10.389315545391828, 7.813542374905532]

# %% [markdown]
# ## Display the interactive map

# %%
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[44.985330552541846, 8.014483361469685], controls=(WidgetControl(options=['position', 'transparent_…
