# %% [markdown]
# ## Import libraries

# %%
import ee
import geemap

# %% [markdown]
# ## Create an interactive map

# %%
Map = geemap.Map(center=[40, -100], zoom=4)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Add Earth Engine Python script

# %%
# Add Earth Engine dataset
image = ee.Image("USGS/SRTMGL1_003")

#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Chapter:      F4.7 Interpreting Time Series with CCDC
#  Checkpoint:   F47e
#  Authors:      Paulo Arévalo, Pontus Olofsson
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# Load the required libraries.
from modules import palettes_geemap as palettes
from modules import api_geemap as utils

# Load the results.
resultsPath = \
'projects/gee-book/assets/F4-7/Rondonia_example_small'
ccdResults = ee.Image(resultsPath)
Map.centerObject(ccdResults, 10)

# Convert a date into fractional years.
inputDate = '2005-09-25'
dateParams = {
    'inputFormat': 3,
    'inputDate': inputDate,
    'outputFormat': 1
}
formattedDate = utils.Dates.convertDate(dateParams)

# Band names originally used as inputs to the CCD algorithm.
BANDS = ['BLUE', 'GREEN', 'RED', 'NIR', 'SWIR1', 'SWIR2']

# Names for the time segments to retrieve.
SEGS = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9',
'S10'
]

# Transform CCD results into a multiband image.
ccdImage = utils.CCDC.buildCcdImage(ccdResults, len(SEGS),
BANDS)
print(ccdImage.getInfo())

# Define bands to select.
SELECT_BANDS = ['RED', 'GREEN', 'BLUE', 'NIR']

# Define coefficients to select.
# This list contains all possible coefficients, and the RMSE
SELECT_COEFS = ['INTP', 'SLP', 'RMSE']

# Obtain coefficients.
coefs = utils.CCDC.getMultiCoefs(
ccdImage, formattedDate, SELECT_BANDS, SELECT_COEFS, True,
SEGS, 'after')
print(coefs.getInfo())

# Show a single coefficient.
slpVisParams = {
    'palette': palettes.matplotlib['viridis'][7],
    'min': -0.0005,
    'max': 0.005
}
Map.addLayer(coefs.select('RED_SLP'), slpVisParams,
'RED SLOPE 2005-09-25')

rmseVisParams = {
    'palette': palettes.matplotlib['viridis'][7],
    'min': 0,
    'max': 0.1
}
Map.addLayer(coefs.select('NIR_RMSE'), rmseVisParams,
'NIR RMSE 2005-09-25')

# Show an RGB with three coefficients.
rgbVisParams = {
    'bands': ['RED_INTP', 'GREEN_INTP', 'BLUE_INTP'],
    'min': 0,
    'max': 0.1
}
Map.addLayer(coefs, rgbVisParams, 'RGB 2005-09-25')

#  -----------------------------------------------------------------------
#  CHECKPOINT
#  -----------------------------------------------------------------------
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'Image', 'bands': [{'id': 'S1_BLUE_coef_INTP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S1_BLUE_coef_SLP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S1_BLUE_coef_COS', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S1_BLUE_coef_SIN', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S1_BLUE_coef_COS2', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S1_BLUE_coef_SIN2', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S1_BLUE_coef_COS3', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S1_BLUE_coef_SIN3', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_INTP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_SLP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_COS', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_SIN', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_COS2', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_SIN2', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_COS3', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'S2_BLUE_coef_SIN3', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [3557, 2042], 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, - ...
# {'type': 'Image', 'bands': [{'id': 'RED_INTP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'GREEN_INTP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'BLUE_INTP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'NIR_INTP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'RED_SLP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'GREEN_SLP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'BLUE_SLP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'NIR_SLP', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'RED_RMSE', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'GREEN_RMSE', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'BLUE_RMSE', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}, {'id': 'NIR_RMSE', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'crs': 'EPSG:4326', 'crs_transform': [0.00026949458523585647, 0, -64.91181327283456, 0, -0.00026949458523585647, -10.131379437356788]}]}

# %% [markdown]
# ## Display the interactive map

# %%
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-10.406586101633938, -64.43251713012738], controls=(WidgetControl(options=['position', 'transparen…
